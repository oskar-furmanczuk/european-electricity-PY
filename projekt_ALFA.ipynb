# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_tr = 'C:\\projekt_ALFA\\Supply, transformation and consumption of electricity_1990-2017_EUROSTAT.tsv'

# %%
file = pd.read_csv(file_tr, sep='\t')

# %%
print(type(file))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
file.head()
# Out:
#   nrg_bal,siec,unit,geo\time       2017        2016        2015        2014   \
# 0           AFC,E7000,GWH,AL   6136.388    5674.000    6015.000    6656.000
# 1           AFC,E7000,GWH,AT  65286.469   64427.642   63482.625   62557.420
# 2           AFC,E7000,GWH,BA  11785.000   11494.000   11924.000   11877.000
# 3           AFC,E7000,GWH,BE  83774.200   83353.000   83145.000   82219.000
# 4           AFC,E7000,GWH,BG  31445.466   30354.000   29647.000   28945.000
#
#         2013        2012        2011        2010        2009   ...  \
# 0   7325.000    6137.000    6407.000    5656.000    5369.000   ...
# 1  63546.708   62952.105   62132.291   62071.793   59201.268   ...
# 2          :           :           :           :           :   ...
# 3  84162.000   83867.000   83413.000   85968.000   79741.000   ...
# 4  28697.000   29223.000   29659.000   28349.000   28317.000   ...
#
#         1999        1998        1997        1996        1995        1994   \
# ...

# %%
file.columns = ['types', '2017', '2016', '2015', '2014', '2013',
       '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
       '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995',
       '1994', '1993', '1992', '1991', '1990']

# %%
file[['nrg_bal','siec','unit','geo\time']] = file.types.str.split(",",expand=True)

# %%
file.columns
# Out:
# Index(['types', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010',
#        '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001',
#        '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992',
#        '1991', '1990', 'nrg_bal', 'siec', 'unit', 'geo\time'],
#       dtype='object')

# %%
df = file[['nrg_bal', 'geo\time','siec', 'unit',  '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010',
       '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001',
       '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992',
       '1991', '1990',]]

# %%
df.columns = ['type', 'country code', 'standard', 'unit', '2017', '2016', '2015', '2014',
       '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005',
       '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996',
       '1995', '1994', '1993', '1992', '1991', '1990']

# %%
df.head()
# Out:
#   type country code standard unit        2017        2016        2015  \
# 0  AFC           AL    E7000  GWH   6136.388    5674.000    6015.000
# 1  AFC           AT    E7000  GWH  65286.469   64427.642   63482.625
# 2  AFC           BA    E7000  GWH  11785.000   11494.000   11924.000
# 3  AFC           BE    E7000  GWH  83774.200   83353.000   83145.000
# 4  AFC           BG    E7000  GWH  31445.466   30354.000   29647.000
#
#          2014        2013        2012  ...        1999        1998  \
# 0   6656.000    7325.000    6137.000   ...   4367.000    2277.000
# 1  62557.420   63546.708   62952.105   ...  51846.000   50699.000
# 2  11877.000           :           :   ...          :           :
# 3  82219.000   84162.000   83867.000   ...  76050.000   75527.000
# 4  28945.000   28697.000   29223.000   ...  25390.000   27789.000
#
#          1997        1996        1995        1994        1993        1992  \
# 0   2148.000    2818.000    2084.000    1875.000    1697.000    1444.000
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
csv_output = 'C:\\projekt_ALFA\\output.xlsx'
df.to_excel(csv_output)

# %%
dict_countries = {
'EU28':'European Union - 28 countries',
'EA19':'Euro area (19 countries)',
'BE':'Belgium',
'BG':'Bulgaria', 
'CZ':'Czechia' ,
'DK':'Denmark',
'DE':'Germany (until 1990 former territory of the FRG)',
'EE':'Estonia',
'IE':'Ireland',
'EL':'Greece',
'ES':'Spain',
'FR':'France',
'HR':'Croatia',
'IT':'Italy',
'CY':'Cyprus',
'LV':'Latvia',
'LT':'Lithuania',
'LU':'Luxembourg',
'HU':'Hungary',
'MT':'Malta',
'NL':'Netherlands',
'AT':'Austria',
'PL':'Poland',
'PT':'Portugal',
'RO':'Romania',
'SI':'Slovenia',
'SK':'Slovakia',
'FI':'Finland',
'SE':'Sweden',
'UK':'United Kingdom',
'IS':'Iceland',
'LI':'Liechtenstein',
'NO':'Norway',
'ME':'Montenegro',
'MK':'North Macedonia',
'AL':'Albania',
'RS':'Serbia',
'TR':'Turkey',
'BA':'Bosnia and Herzegovina',
'XK':'Kosovo (under United Nations Security Council Resolution 1244/99)',
'MD':'Moldova',
'UA':'Ukraine',
'GE':'Georgia'}

# %%
dict_countries['UA']
# Out:
# 'Ukraine'

# %%
df.iloc[3,1]
# Out:
# 'BE'

# %%
col_countries_names = []
for i,j in df.iterrows():
    for k in dict_countries.keys():
        if k == df.iloc[i,1]:
            col_countries_names.append(dict_countries[k])

# %%
df['country'] = col_countries_names

# %%
df.columns
# Out:
# Index(['type', 'country code', 'standard', 'unit', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006',
#        '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997',
#        '1996', '1995', '1994', '1993', '1992', '1991', '1990', 'country'],
#       dtype='object')

# %%
df = df[['type', 'country code',  'country','standard', 'unit', '2017', '2016', '2015',
       '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006',
       '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997',
       '1996', '1995', '1994', '1993', '1992', '1991', '1990']]

# %%
df
# Out:
#                  type country code                 country standard unit  \
# 0                 AFC           AL                 Albania    E7000  GWH
# 1                 AFC           AT                 Austria    E7000  GWH
# 2                 AFC           BA  Bosnia and Herzegovina    E7000  GWH
# 3                 AFC           BE                 Belgium    E7000  GWH
# 4                 AFC           BG                Bulgaria    E7000  GWH
# ...               ...          ...                     ...      ...  ...
# 1583  TI_EHG_EPS_PURE           SE                  Sweden    E7000  GWH
# 1584  TI_EHG_EPS_PURE           SI                Slovenia    E7000  GWH
# 1585  TI_EHG_EPS_PURE           SK                Slovakia    E7000  GWH
# 1586  TI_EHG_EPS_PURE           UA                 Ukraine    E7000  GWH
# 1587  TI_EHG_EPS_PURE           UK          United Kingdom    E7000  GWH
#
#             2017        2016        2015        2014        2013  ...  \
# ...

# %%
df_poland = df[df['country'] =='Poland']
df_poland_FC = df_poland[df_poland['type']=='FC']
p = df_poland_FC.iloc[:,5:]
p.columns
p.values
p
# Out:
#             2017         2016         2015         2014         2013  \
# 155  146424.864   143762.500   138926.620   136307.473   134481.000
#
#             2012         2011         2010         2009         2008  ...  \
# 155  133278.000   132388.000   129424.000   122303.000   127350.000   ...
#
#             1999         1998         1997         1996         1995  \
# 155  107026.000   108661.000   108851.000   107293.000   103810.000
#
#             1994        1993        1992         1991         1990
# 155  100003.000   99335.000   98444.000   102833.000   109195.000
#
# [1 rows x 28 columns]

# %%
p= p.astype('float64') 
plt.plot(np.arange(len(p.values[0])),p.values[0])
plt.xticks(np.arange(len(p.values[0])), p.columns)
plt.show()

# %%
round(float(p.values[0][2]))
# Out:
# 138927
